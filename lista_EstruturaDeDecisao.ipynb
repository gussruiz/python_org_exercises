# %%
#Faça um Programa que peça dois números e imprima o maior deles.

num1 = float(input("Informe um número: "))
num2 = float(input("Informe outro número: "))

if num1 > num2:
  print(f'O primeiro número informado é o maior. Número {num1}')
else:
  print(f'O segundo número informado é o maior. Número {num2}')
# Out:
# Informe um número: 47
# Informe outro número: 12
# O primeiro número informado é o maior. Número 47.0

# %%
#Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

num = float(input("Informe um número: "))

if num > 0:
  print(f'O número informado é positvo. Número {num}')
elif num < 0:
  print(f'O número informado é o negativo. Número {num}')
else:
  print('O número informado é zero.')
# Out:
# Informe um número: 1
# O número informado é positvo. Número 1.0

# %%
#Faça um Programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

sex = input("Informe seu sexo biológico com a letra inicial dele: ")

if sex == 'F' or sex == "f":
  print('F - Feminino')
elif sex == 'M' or sex == "m":
  print('M - Masculino')
else:
  print('Sexo Inválido')
# Out:
# Informe seu sexo biológico com a letra inicial dele: m
# M - Masculino

# %%
#Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

letter = input('Informe uma letra por favor: ')

letter = letter.lower()

if letter in 'aeiou':
  print('A letra é uma vogal.')
elif letter.isalpha():
  print('A letra é uma consoante.')
else:
  print('Não foi informado uma letra.')
# Out:
# Informe uma letra por favor: g
# A letra é uma consoante.

# %%
#Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
#   A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
#   A mensagem "Reprovado", se a média for menor do que sete;
#   A mensagem "Aprovado com Distinção", se a média for igual a dez.

grade1 = float(input('Informe a primeira nota do aluno: '))
grade2 = float(input('Informe a segunda nota do aluno: '))

avrg = (grade1 + grade2) / 2

if avrg == 10:
   print(f"Aluno aprovado com Distinção. Nota: {avrg}")
elif avrg >= 7:
  print(f"Aluno aprovado com média: {avrg}")
else:
  print(f"Aluno reprovado com média: {avrg}")
# Out:
# Informe a primeira nota do aluno: 10
# Informe a segunda nota do aluno: 9
# Aluno aprovado com média: 9.5

# %%
#Faça um Programa que leia três números e mostre o maior deles.

num1 = float(input("Informe o primeiro número: "))
num2 = float(input("Informe o segundo número: "))
num3 = float(input("Informe o terceiro número: "))

if num1>num2 and num1>num3:
  print(f'O primeiro número informado é o maior. Número {num1}')
elif num2>num1 and num2>num3:
  print(f'O segundo número informado é o maior. Número {num2}')
else:
  print(f'O terceiro número informado é o maior. Número {num3}')
# Out:
# Informe o primeiro número: 1
# Informe o segundo número: 2
# Informe o terceiro número: 3
# O terceiro número informado é o maior. Número 3.0

# %%
#Faça um Programa que leia três números e mostre o maior e o menor deles.

num1 = float(input("Informe o primeiro número: "))
num2 = float(input("Informe o segundo número: "))
num3 = float(input("Informe o terceiro número: "))

if num1<num2 and num1<num3:
  print(f'O primeiro número informado é o menor. Número {num1}')
elif num2<num1 and num2<num3:
  print(f'O segundo número informado é o menor. Número {num2}')
else:
  print(f'O terceiro número informado é o menor. Número {num3}')
# Out:
# Informe o primeiro número: 5
# Informe o segundo número: 4
# Informe o terceiro número: 1
# O terceiro número informado é o menor. Número 1.0

# %%
#Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

prod1 = float(input("Informe o preço primeiro produto: "))
prod2 = float(input("Informe o preço segundo produto: "))
prod3 = float(input("Informe o preço terceiro produto: "))

if prod1<prod2 and prod1<prod3:
  print(f'O primeiro produto informado é o menor. Preço do produto {prod1}')
elif prod2<prod1 and prod2<prod3:
  print(f'O segundo produto informado é o menor. Preço do produto {prod2}')
else:
  print(f'O terceiro produto informado é o menor. Preço do produto {prod3}')
# Out:
# Informe o preço primeiro produto: 10.00
# Informe o preço segundo produto: 11.00
# Informe o preço terceiro produto: 9.99
# O terceiro produto informado é o menor. Preço do produto 9.99

# %%
#Faça um Programa que leia três números e mostre-os em ordem decrescente.

num1 = float(input('Informe o primeiro número: '))
num2 = float(input('Informe o segundo número: '))
num3 = float(input('Informe o terceiro número: '))

if num1 > num2 and num1 > num3:
    print('O maior número é', num1)
    if num2 > num3:
        print('O segundo maior número é', num2)
        print('O terceiro maior número é', num3)
    else:
        print('O segundo maior número é', num3)
        print('O terceiro maior número é', num2)
elif num2 > num1 and num2 > num3:
    print('O maior número é', num2)
    if num1 > num3:
        print('O segundo maior número é', num1)
        print('O terceiro maior número é', num3)
    else:
        print('O segundo maior número é', num3)
        print('O terceiro maior número é', num1)
elif num3 > num1 and num3 > num2:
    print('O maior número é', num3)
    if num1 > num2:
        print('O segundo maior número é', num1)
        print('O terceiro maior número é', num2)
    else:
        print('O segundo maior número é', num2)
        print('O terceiro maior número é', num1)
# Out:
# Digite o primeiro número: 27
# Digite o segundo número: 42
# Digite o terceiro número: 1
# Números em ordem decrescente: 42.0 27.0 1.0

# %%
#Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
#Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

period = input("Informe o periodo em que estuda: ")

if period == 'M' or period == "m":
  print('Bom Dia!')
elif period == 'V' or period == "v":
  print('Boa Tarde!')
elif period == 'N' or period == "n":
  print('Boa Noite!')
else:
  print('Valor Inválido!')
# Out:
# Informe o periodo em que estuda: n
# Boa Noite!

# %%
#As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
#Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no salário atual:
#   salários até R$ 280,00 (incluindo) : aumento de 20%
#   salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#   salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#   salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#   o salário antes do reajuste;
#   o percentual de aumento aplicado;
#   o valor do aumento;
#   o novo salário, após o aumento.

wage = float(input('Informe o salário do colaborador: '))

if wage > 0  and wage <= 280.00:
  print(f'O salário atual do funcionário é de {wage}')
  print('O aumento do será em 20%')
  wage_raise = (wage / 100) * 20
  new_wage = wage + wage_raise
  print(f'O valor do aumento será de: {wage_raise}')
  print(f'O valor novo salário será: {new_wage}')
elif wage > 280.00 and wage <= 700.00:
    print(f'O salário atual do funcionário é de {wage}')
    print('O aumento do será em 15%')
    wage_raise = (wage / 100) * 15
    new_wage = wage + wage_raise
    print(f'O valor do aumento será de: {wage_raise}')
    print(f'O valor novo salário será: {new_wage}')
elif wage > 700.00 and wage <= 1500.00:
    print(f'O salário atual do funcionário é de {wage}')
    print('O aumento do será em 10%')
    wage_raise = (wage / 100) * 10
    new_wage = wage + wage_raise
    print(f'O valor do aumento será de: {wage_raise}')
    print(f'O valor novo salário será: {new_wage}')
elif wage > 1500.00:
    print(f'O salário atual do funcionário é de {wage}')
    print('O aumento do será em 5%')
    wage_raise = (wage / 100) * 5
    new_wage = wage + wage_raise
    print(f'O valor do aumento será de: {wage_raise}')
    print(f'O valor novo salário será: {new_wage}')
else:
  print('Valor Inválido!')
# Out:
# Informe o salário do colaborador: 127
# O salário atual do funcionário é de 127.0
# O aumento do será em 20%
# O valor do aumento será de: 25.4
# O valor novo salário será: 152.4

# %%
#Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo)
#e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos.
#O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.
#   Desconto do IR:
#   Salário Bruto até 900 (inclusive) - isento
#   Salário Bruto até 1500 (inclusive) - desconto de 5%
#   Salário Bruto até 2500 (inclusive) - desconto de 10%
#   Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo abaixo.

valor_hora = float(input('Informe o valor da hora R$: '))
qtd_horas = int(input('Informe a quantidade de horas trabalhadas: '))
salario = valor_hora * qtd_horas
print(f'Salário Bruto: ({valor_hora:.2f} * {qtd_horas})\t: R$ {salario:.2f}')

if salario <= 900:
    percentual = 0
elif salario <= 1500:
    percentual = 0.05
elif salario <= 2500:
    percentual = 0.1
else:
    percentual = 0.2

ir = percentual * salario
inss = 0.1 * salario
fgts = 0.11 * salario
total_desconto = ir + inss
salario_liquido = salario - total_desconto
print(f'(-) IR ({percentual:.0%}):\t\t\t: R$ {ir:.2f}')
print(f'(-) INSS ({0.1:.0%}):\t\t\t: R$ {inss:.2f}')
print(f'FGTS ({0.11:.0%}):\t\t\t: R$ {fgts:.2f}')
print(f'Total de descontos:\t\t: R$ {total_desconto:.2f}')
print(f'Salário Líquido:\t\t: R$ {salario_liquido:.2f}')
# Out:
# Informe o valor da hora R$: 5
# Informe a quantidade de horas trabalhadas: 220
# Salário Bruto: (5.00 * 220)	: R$ 1100.00
# (-) IR (5%):			: R$ 55.00
# (-) INSS (10%):			: R$ 110.00
# FGTS (11%):			: R$ 121.00
# Total de descontos:		: R$ 165.00
# Salário Líquido:		: R$ 935.00

# %%
#Faça um Programa que leia um número e exiba o dia correspondente da semana. (1-Domingo, 2- Segunda, etc.), se digitar outro valor deve aparecer valor inválido.

day = int(input('Informe o número equivalente ao dia da semana: '))

if day == 1:
  print('Domingo')
elif day == 2:
  print('Segunda')
elif day == 3:
  print('Terça')
elif day == 4:
  print('Quarta')
elif day == 5:
  print('Quinta')
elif day == 6:
  print('Sexta')
elif day == 7:
  print('Sabádo')
else:
  print('Input inválido!')
# Out:
# Informe o número equivalente ao dia da semana: 4
# Quarta

# %%
#Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule a sua média. A atribuição de conceitos obedece à tabela abaixo:
#  Média de Aproveitamento  Conceito
#  Entre 9.0 e 10.0        A
#  Entre 7.5 e 9.0         B
#  Entre 6.0 e 7.5         C
# Entre 4.0 e 6.0          D
#  Entre 4.0 e zero        E
#O algoritmo deve mostrar na tela as notas, a média, o conceito correspondente e a mensagem “APROVADO” se o conceito for A, B ou C ou “REPROVADO” se o conceito for D ou E.


grade1 = float(input('Informe a primeira nota do aluno: '))
grade2 = float(input('Informe a segunda nota do aluno: '))

avrg = (grade1 + grade2) / 2

if avrg > 9 and avrg <= 10:
  print(f'A nota 1 do aluno é {grade1}')
  print(f'A nota 2 do aluno é {grade2}')
  print(f'A média do aluno é {avrg}')
  print('A - Aprovado')
elif avrg > 7.5 and avrg <= 9:
  print(f'A nota 1 do aluno é {grade1}')
  print(f'A nota 2 do aluno é {grade2}')
  print(f'A média do aluno é {avrg}')
  print('B - Aprovado')
elif avrg > 6 and avrg <= 7.5:
  print(f'A nota 1 do aluno é {grade1}')
  print(f'A nota 2 do aluno é {grade2}')
  print(f'A média do aluno é {avrg}')
  print('C - Aprovado')
elif avrg > 4 and avrg <= 6:
  print(f'A nota 1 do aluno é {grade1}')
  print(f'A nota 2 do aluno é {grade2}')
  print(f'A média do aluno é {avrg}')
  print('D - Reprovado')
elif avrg > 0 and avrg <= 4:
  print(f'A nota 1 do aluno é {grade1}')
  print(f'A nota 2 do aluno é {grade2}')
  print(f'A média do aluno é {avrg}')
  print('E - Reprovado')
else:
  print('Inputs inválidos')
# Out:
# Informe a primeira nota do aluno: 8.5
# Informe a segunda nota do aluno: 8
# A nota 1 do aluno é 8.5
# A nota 2 do aluno é 8.0
# A média do aluno é 8.25
# B - Aprovado

# %%
#Faça um Programa que peça os 3 lados de um triângulo. O programa deverá informar se os valores podem ser um triângulo. Indique, caso os lados formem um triângulo, se o mesmo é: equilátero, isósceles ou escaleno.
# Dicas:
#   Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
#   Triângulo Equilátero: três lados iguais;
#   Triângulo Isósceles: quaisquer dois lados iguais;
#   Triângulo Escaleno: três lados diferentes;

side1 = float(input('Iforme o primeiro lado do triangulo: '))
side2 = float(input('Iforme o segundo lado do triangulo: '))
side3 = float(input('Iforme o terceiro lado do triangulo: '))

if side1 + side2 > side3 or side1 + side3 > side2 or side2 + side3 > side1:
  if side1 == side2 and side2 == side3 and side1 == side2:
    print('É um triangulo Equilátero')
  elif side1 == side2 or side1 == side3 or side2 == side3:
    print('É um triangulo Isóceles')
  else:
    print('É um triangulo Escaleno')
else:
  print("Os valores informados não correspondem a um triangulo.")
# Out:
# Iforme o primeiro lado do triangulo: 3
# Iforme o segundo lado do triangulo: 3
# Iforme o terceiro lado do triangulo: 3
# É um triangulo Equilátero

# %%
#Faça um programa que calcule as raízes de uma equação do segundo grau, na forma ax2 + bx + c. O programa deverá pedir os valores de a, b e c e fazer as consistências, informando ao usuário nas seguintes situações:
# Se o usuário informar o valor de A igual a zero, a equação não é do segundo grau e o programa não deve fazer pedir os demais valores, sendo encerrado;
# Se o delta calculado for negativo, a equação não possui raizes reais. Informe ao usuário e encerre o programa;
# Se o delta calculado for igual a zero a equação possui apenas uma raiz real; informe-a ao usuário;
# Se o delta for positivo, a equação possui duas raiz reais; informe-as ao usuário;

a = float(input('Informe um valor para A: '))

if a == 0:
  print('Não é possivel fazer a conta com o valor de A sendo 0')
else:
  b = float(input('Informe o valor para B: '))
  c = float(input('Informe o valor para c: '))

  delta = b**2 - 4 * a * c

  if delta < 0:
    print('A equação não possui raizes reais')
  elif delta == 0:
    x = (-b + delta ** (1/2)) / (2*a)
    print('A raiz de x é: ', x)
  else:
    x1 = (-b + delta ** (1/2)) / (2*a)
    x2 = (-b - delta ** (1/2)) / (2*a)

    print('A raiz de x1 é: ', x1)
    print('A raiz de x2 é: ', x2)
# Out:
# Informe um valor para A: 2
# Informe o valor para B: 5
# Informe o valor para c: 3
# A raiz de x1 é:  -1.0
# A raiz de x2 é:  -1.5

# %%
#Faça um Programa que peça um número correspondente a um determinado ano e em seguida informe se este ano é ou não bissexto.

jahr = int(input('Informe o ano: '))

if (jahr % 4 == 0 and jahr % 100 != 0) or jahr % 400 == 0:
  print(f'O ano {jahr} é bissexto.')
else:
  print(f'O ano {jahr} não é bissexto.')
# Out:
# Informe o ano: 100
# O ano 100 não é bissexto.

# %%
#Faça um Programa que peça uma data no formato dd/mm/aaaa e determine se a mesma é uma data válida.

data = input('Informe a data no formato dd/mm/aaaa: ')

data = data.split('/')
dia = int(data[0])
mes = int(data[1])
ano = int(data[2])

bissexto = False
if (ano % 4 == 0 and ano % 100 != 0) or ano % 400 == 0:
    bissexto = True

if not 0 < dia < 32:
    print('Dia inválido')
elif not 0 < mes < 13:
    print('Mês inválido')
elif dia == 31 and not mes in [1, 3, 5, 7, 8, 10, 12]:
    print('O mês', mes, 'não possui 31 dias.')
elif dia == 30 and mes == 2:
    print('O mês 2 não possui 30 dias.')
elif dia == 29 and mes == 2 and not bissexto:
    print('O mês 2 no ano', ano, 'não possuiu 29 dias.')
else:
    print('Data válida')
# Out:
# Informe a data no formato dd/mm/aaaa: 18/02/2002
# Data válida

# %%
#Faça um Programa que leia um número inteiro menor que 1000 e imprima a quantidade de centenas, dezenas e unidades do mesmo.
#   Observando os termos no plural a colocação do "e", da vírgula entre outros. Exemplo:
#   326 = 3 centenas, 2 dezenas e 6 unidades
#   12 = 1 dezena e 2 unidades Testar com: 326, 300, 100, 320, 310,305, 301, 101, 311, 111, 25, 20, 10, 21, 11, 1, 7 e 16

num = int(input('Informe um número menor que 1000: '))

if 0 < num <= 1000:
  centenas = int(num / 100)
  print(f'O número tem {centenas} centenas')
  dezenas = int((num - centenas * 100) / 10)
  print(f'O número tem {dezenas} dezenas')
  unidades = int((num - (centenas*100) - (dezenas * 10)))
  print(f'O número tem {unidades} unidades')

else:
  print('O número é inválido.')
# Out:
# Informe um número menor que 1000: 111
# O número tem 1 centenas
# O número tem 1 dezenas
# O número tem 1 unidades

# %%
#Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e presentar:
#   A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
#   A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
#   A mensagem "Aprovado com Distinção", se a média for igual a 10.

grade1 = float(input('Informe a primeira nota do aluno: '))
grade2 = float(input('Informe a segunda nota do aluno: '))
grade3 = float(input('Informe a terceira nota do aluno: '))

avrg = (grade1 + grade2 + grade3) / 3

if avrg == 10:
   print(f"Aluno aprovado com Distinção. Nota: {avrg}")
elif avrg >= 7:
  print(f"Aluno aprovado com média: {avrg}")
else:
  print(f"Aluno reprovado com média: {avrg}")
# Out:
# Informe a primeira nota do aluno: 0
# Informe a segunda nota do aluno: 0
# Informe a terceira nota do aluno: 0
# Aluno reprovado com média: 0.0

# %%
#Faça um Programa para um caixa eletrônico. O programa deverá perguntar ao usuário a valor do saque e depois informar quantas notas de cada valor serão fornecidas.
#As notas disponíveis serão as de 1, 5, 10, 50 e 100 reais. O valor mínimo é de 10 reais e o máximo de 600 reais. O programa não deve se preocupar com a quantidade de notas existentes na máquina.
#   Exemplo 1: Para sacar a quantia de 256 reais, o programa fornece duas notas de 100, uma nota de 50, uma nota de 5 e uma nota de 1;
#   Exemplo 2: Para sacar a quantia de 399 reais, o programa fornece três notas de 100, uma nota de 50, quatro notas de 10, uma nota de 5 e quatro notas de 1.

num = int(input('Informe a ser sacado: '))

if 10 < num <= 600:
  centenas = int(num / 100)
  cinquentas = int((num - centenas * 100) / 50)
  dezenas = int((num - centenas * 100 - (cinquentas * 50)) / 10)
  unidades = int((num - (centenas*100) - (dezenas * 10) - (cinquentas * 50)))

  print(f'{centenas} nota(s) de R$100.00')
  print(f'{cinquentas} nota(s) de R$50.00')
  print(f'{dezenas} nota(s) de R$10.00')
  print(f'{unidades} nota(s) de R$1.00')

else:
  print('Valor inválido.')
# Out:
# Informe a ser sacado: 176
# 1 nota(s) de R$100.00
# 1 nota(s) de R$50.00
# 2 nota(s) de R$10.00
# 6 nota(s) de R$1.00

# %%
#Faça um Programa que peça um número inteiro e determine se ele é par ou impar. Dica: utilize o operador módulo (resto da divisão).

num = int(input('Infome um númeor inteiro: '))

if num % 2 == 0:
  print(f'O número {num} é par')
else:
  print(f'O número {num} é impar')
# Out:
# Infome um númeor inteiro: 3
# O número 3 é impar

# %%
#Faça um Programa que peça um número e informe se o número é inteiro ou decimal. Dica: utilize uma função de arredondamento.

num = float(input('Infome um númeor: '))

if num == int(num):
  print(f'O número {num} é inteiro')
else:
  print(f'O número {num} é decimal')
# Out:
# Infome um númeor: 23.5
# O número 23.5 é decimal

# %%
#Faça um Programa que leia 2 números e em seguida pergunte ao usuário qual operação ele deseja realizar. O resultado da operação deve ser acompanhado de uma frase que diga se o número é:
#   par ou ímpar;
#   positivo ou negativo;
#   inteiro ou decimal.

num1 = float(input('Informe um número: '))
num2 = float(input('Informe outro número: '))

op = input('Informe a operação que deseja realizar: +, -, *, /  ')

if op == '+':
  result = num1 + num2
elif op == '-':
  result = num1 - num2
elif op == '*':
  result = num1 * num2
elif op == '/':
  result == num1 / num2
else:
  print('Operação informada inválida!')

if result > 0:
  print('O número é positivo')
elif result < 0:
  print('O número é negativo')
else:
  print('O número é zero')

if result == int(result):
  print('O número é inteiro')
  if result % 2 == 0:
    print('O número é par')
  else:
    print('O númeor é impar')
else:
  print('O número o é decimal')
# Out:
# Informe um número: 10
# Informe outro número: 12.5
# Informe a operação que deseja realizar: : +, -, *, /+
# O número é positivo
# O número o é decimal

# %%
#Faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
#   "Telefonou para a vítima?"
#   "Esteve no local do crime?"
#   "Mora perto da vítima?"
#   "Devia para a vítima?"
#   "Já trabalhou com a vítima?"
#O programa deve no final emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice"
#e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".

total = int(0)

resp = input('Telefonou para a vítima? ')

if resp == "sim" or resp == "Sim":
  total += 1

resp = input('Esteve no local do crime? ')

if resp == "sim" or resp == "Sim":
  total += 1

resp = input('Mora perto da vítima? ')

if resp == "sim" or resp == "Sim":
  total += 1

resp = input('Devia para a vítima? ')

if resp == "sim" or resp == "Sim":
  total += 1

resp = input('Já trabalhou com a vítima? ')

if resp == "sim" or resp == "Sim":
  total += 1


if total == 2:
  print('Suspeita')
elif 2 < total < 5:
  print('Cúmplice')
elif total == 5:
  print('Assassino')
else:
  print('Inocente')
# Out:
# Telefonou para a vítima? sim
# Esteve no local do crime? não
# Mora perto da vítima? sim
# Devia para a vítima? não
# Já trabalhou com a vítima? não
# Suspeita

# %%
#Um posto está vendendo combustíveis com a seguinte tabela de descontos:
#   Álcool:
#       até 20 litros, desconto de 3% por litro
#       acima de 20 litros, desconto de 5% por litro
#   Gasolina:
#       até 20 litros, desconto de 4% por litro
#       acima de 20 litros, desconto de 6% por litro
#Escreva um algoritmo que leia o número de litros vendidos, o tipo de combustível (codificado da seguinte forma: A-álcool, G-gasolina), calcule e imprima o valor a ser pago pelo cliente sabendo-se
#que o preço do litro da gasolina é R$ 2,50 o preço do litro do álcool é R$ 1,90.

tipo = input('Informe o tipo de combustivel consumido (G-gasolina, A-álcool): ')
qnt = float(input('Informe quantos litros foram consumidos: '))

if tipo == "G":
  if qnt <= 20:
    valor =  (qnt * 2.5) * 0.96
  else:
    valor =  (qnt * 2.5) * 0.94
else:
    if qnt <= 20:
      valor =  (qnt * 1.9) * 0.97
    else:
      valor =  (qnt * 1.9) * 0.94

print('Valor a ser pago: ', valor)
# Out:
# Informe o tipo de combustivel consumido (G-gasolina, A-álcool): A
# Informe quantos litros foram consumidos: 20
# Valor a ser pago:  36.86

# %%
#Uma fruteira está vendendo frutas com a seguinte tabela de preços:
#                       Até 5 Kg           Acima de 5 Kg
# Morango         R$ 2,50 por Kg          R$ 2,20 por Kg
# Maçã            R$ 1,80 por Kg          R$ 1,50 por Kg
#Se o cliente comprar mais de 8 Kg em frutas ou o valor total da compra ultrapassar R$ 25,00, receberá ainda um desconto de 10% sobre este total.
#Escreva um algoritmo para ler a quantidade (em Kg) de morangos e a quantidade (em Kg) de maças adquiridas e escreva o valor a ser pago pelo cliente.

berry = float(input('Informe quantos quilos de morango foram comprados: '))
apple = float(input('Informe quantos quilos de maçã foram comprados: '))


if berry > 5:
  price_berry = berry * 2.20
else:
  price_berry = berry * 2.50

if apple > 5:
  price_apple = apple * 1.50
else:
  price_apple = apple * 1.80

total_weight = apple + berry
total_price = price_berry + price_berry

if total_weight < 8 or total_price > 25:
  new_price = total_price * 0.90
  print('O preço a ser pago é: ', new_price)
else:
  print('O preço a ser pago é: ', total_price)
# Out:
# Informe quantos quilos de morango foram comprados: 1
# Informe quantos quilos de maçã foram comprados: 2
# O preço a ser pago é:  4.5

# %%
#O Hipermercado Tabajara está com uma promoção de carnes que é imperdível. Confira:
#
#                        Até 5 Kg           Acima de 5 Kg
#  File Duplo      R$ 4,90 por Kg          R$ 5,80 por Kg
#  Alcatra         R$ 5,90 por Kg          R$ 6,80 por Kg
#  Picanha         R$ 6,90 por Kg          R$ 7,80 por Kg
#
#Para atender a todos os clientes, cada cliente poderá levar apenas um dos tipos de carne da promoção, porém não há limites para a quantidade de carne por cliente. Se compra for feita
#no cartão Tabajara o cliente receberá ainda um desconto de 5% sobre o total da compra. Escreva um programa que peça o tipo e a quantidade de carne comprada pelo usuário e gere um cupom
#fiscal, contendo as informações da compra: tipo e quantidade de carne, preço total, tipo de pagamento, valor do desconto e valor a pagar.

meat = input('Informe qual tipo de carne deseja levar: ')
kilos = float(input('Informe quantos quilos de carne deseja levar: '))

if meat == 'f' or meat == 'F':
  if kilos <= 5:
    price = kilos * 4.90
  else:
    price = kilos * 5.80

  card = input('O pagamento será feito com o cartão da loja? ')
  if card == 'sim' or card == 'Sim':
    new_price = price * 0.95
    print('Tipo de carne: File Duplo')
    print(f'Quantidade: {kilos}Kg')
    print(f'Preço Total: R$ {price}')
    print('Tipo de pagamento: Cartão da Loja')
    print(f'Valor do desconto: R$ {price*0.05}')
    print(f'Valor a ser pago: R$ {new_price}')
  else:
    print('Tipo de carne: File Duplo')
    print(f'Quantidade: {kilos}Kg')
    print(f'Preço Total: R$ {price}')
    print('Tipo de pagamento: Cartão Normal')
    print(f'Valor do desconto: R$ 0')
    print(f'Valor a ser pago: R$ {price}')

elif meat == 'a' or meat == 'A':
  if kilos <= 5:
    price = kilos * 5.90
  else:
    price = kilos * 6.80

  card = input('O pagamento será feito com o cartão da loja? ')
  if card == 'sim' or card == 'Sim':
    new_price = price * 0.95
    print('Tipo de carne: Alcatra')
    print(f'Quantidade: {kilos}Kg')
    print(f'Preço Total: R$ {price}')
    print('Tipo de pagamento: Cartão da Loja')
    print(f'Valor do desconto: R$ {price*0.05}')
    print(f'Valor a ser pago: R$ {new_price}')
  else:
    print('Tipo de carne: Alcatra')
    print(f'Quantidade: {kilos}Kg')
    print(f'Preço Total: R$ {price}')
    print('Tipo de pagamento: Cartão Normal')
    print(f'Valor do desconto: R$ 0')
    print(f'Valor a ser pago: R$ {price}')

elif meat == 'p' or meat == 'P':
  if kilos <= 5:
    price = kilos * 6.90
  else:
    price = kilos * 7.80

  card = input('O pagamento será feito com o cartão da loja? ')
  if card == 'sim' or card == 'Sim':
    new_price = price * 0.95
    print('Tipo de carne: Picanha')
    print(f'Quantidade: {kilos}Kg')
    print(f'Preço Total: R$ {price}')
    print('Tipo de pagamento: Cartão da Loja')
    print(f'Valor do desconto: R$ {price*0.05}')
    print(f'Valor a ser pago: R$ {new_price}')
  else:
    print('Tipo de carne: Picanha')
    print(f'Quantidade: {kilos}Kg')
    print(f'Preço Total: R$ {price}')
    print('Tipo de pagamento: Cartão Normal')
    print(f'Valor do desconto: R$ 0')
    print(f'Valor a ser pago: R$ {price}')
else:
  print('Não foi econtrada esse tipo de carne no estoque.')
# Out:
# Informe qual tipo de carne deseja levar: P
# Informe quantos quilos de carne deseja levar: 10
# O pagamento será feito com o cartão da loja? sim
# Tipo de carne: Picanha
# Quantidade: 10.0Kg
# Preço Total: R$ 78.0
# Tipo de pagamento: Cartão da Loja
# Valor do desconto: R$ 3.9000000000000004
# Valor a ser pago: R$ 74.1
